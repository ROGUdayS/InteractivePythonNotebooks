# %%
import pandas as pd
 

car_selling_data = {'Brand': ['Maruti', 'Maruti', 'Maruti',
                              'Maruti', 'Hyundai', 'Hyundai',
                              'Toyota', 'Mahindra', 'Mahindra',
                              'Ford', 'Toyota', 'Ford'],
                    'Year':  [2010, 2011, 2009, 2013,
                              2010, 2011, 2011, 2010,
                              2013, 2010, 2010, 2011],
                    'Sold': [6, 7, 9, 8, 3, 5,
                             2, 8, 7, 2, 4, 2]}
 

df = pd.DataFrame(car_selling_data)
 

grouped = df.groupby('Year')
print(grouped.get_group(2010))
# Out:
#        Brand  Year  Sold
# 0     Maruti  2010     6
# 4    Hyundai  2010     3
# 7   Mahindra  2010     8
# 9       Ford  2010     2
# 10    Toyota  2010     4

# %%
student_data = {'Name':  ['Amit', 'Praveen', 'Jagroop',
                         'Rahul', 'Vishal', 'Suraj',
                         'Rishab', 'Satyapal', 'Amit',
                         'Rahul', 'Praveen', 'Amit'],
 
                'Roll_no': [23, 54, 29, 36, 59, 38,
                            12, 45, 34, 36, 54, 23],
                'Email': ['xxxx@gmail.com', 'xxxxxx@gmail.com',
                          'xxxxxx@gmail.com', 'xx@gmail.com',
                          'xxxx@gmail.com', 'xxxxx@gmail.com',
                          'xxxxx@gmail.com', 'xxxxx@gmail.com',
                          'xxxxx@gmail.com', 'xxxxxx@gmail.com',
                          'xxxxxxxxxx@gmail.com', 'xxxxxxxxxx@gmail.com']}

df = pd.DataFrame(student_data)
 
non_duplicate = df[~df.duplicated('Roll_no')]
non_duplicate = df[~df.duplicated('Email')]

print(non_duplicate)
# Out:
#        Name  Roll_no                 Email
# 0      Amit       23        xxxx@gmail.com
# 1   Praveen       54      xxxxxx@gmail.com
# 3     Rahul       36          xx@gmail.com
# 5     Suraj       38       xxxxx@gmail.com
# 10  Praveen       54  xxxxxxxxxx@gmail.com

# %%
dataFrame=pd.read_csv(r'/Users/udays/Downloads/LungCap.csv')
print(dataFrame)
# Out:
#      LungCap   Age  Height Smoke  Gender Caesarean
# 0      6.475   6.0    62.1    no    male        no
# 1     10.125  18.0    74.7   yes  female        no
# 2      9.550  16.0    69.7    no  female       yes
# 3     11.125  14.0    71.0    no    male        no
# 4      4.800   5.0    56.9    no    male        no
# ..       ...   ...     ...   ...     ...       ...
# 720    5.725   9.0    56.0    no  female        no
# 721    9.050  18.0    72.0   yes    male       yes
# 722    3.850  11.0    60.5   yes  female        no
# 723    9.825  15.0    64.9    no  female        no
# 724    7.100  10.0    67.7    no    male        no
#
# [725 rows x 6 columns]

# %%
dataFrame.shape
# Out:
# (725, 6)

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LungCap    721 non-null    float64
#  1   Age        722 non-null    float64
#  2   Height     720 non-null    float64
#  3   Smoke      725 non-null    object
#  4   Gender     723 non-null    object
#  5   Caesarean  724 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 34.1+ KB

# %%
dataFrame[dataFrame.isnull()]
# Out:
#      LungCap  Age  Height Smoke Gender Caesarean
# 0        NaN  NaN     NaN   NaN    NaN       NaN
# 1        NaN  NaN     NaN   NaN    NaN       NaN
# 2        NaN  NaN     NaN   NaN    NaN       NaN
# 3        NaN  NaN     NaN   NaN    NaN       NaN
# 4        NaN  NaN     NaN   NaN    NaN       NaN
# ..       ...  ...     ...   ...    ...       ...
# 720      NaN  NaN     NaN   NaN    NaN       NaN
# 721      NaN  NaN     NaN   NaN    NaN       NaN
# 722      NaN  NaN     NaN   NaN    NaN       NaN
# 723      NaN  NaN     NaN   NaN    NaN       NaN
# 724      NaN  NaN     NaN   NaN    NaN       NaN
#
# [725 rows x 6 columns]

# %%
dataFrame.isnull().sum()
# Out:
# LungCap      4
# Age          3
# Height       5
# Smoke        0
# Gender       2
# Caesarean    1
# dtype: int64

# %%
import numpy as np
import pandas as pd 
from pandas import DataFrame,Series 
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as stats 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"/Users/udays/Downloads/LungCap.csv")
df = pd.DataFrame(data)

# %%
data.head()
# Out:
#    LungCap   Age  Height Smoke  Gender Caesarean
# 0    6.475   6.0    62.1    no    male        no
# 1   10.125  18.0    74.7   yes  female        no
# 2    9.550  16.0    69.7    no  female       yes
# 3   11.125  14.0    71.0    no    male        no
# 4    4.800   5.0    56.9    no    male        no

# %%
data.shape
# Out:
# (725, 6)

# %%
data.info
# Out:
# <bound method DataFrame.info of      LungCap   Age  Height Smoke  Gender Caesarean
# 0      6.475   6.0    62.1    no    male        no
# 1     10.125  18.0    74.7   yes  female        no
# 2      9.550  16.0    69.7    no  female       yes
# 3     11.125  14.0    71.0    no    male        no
# 4      4.800   5.0    56.9    no    male        no
# ..       ...   ...     ...   ...     ...       ...
# 720    5.725   9.0    56.0    no  female        no
# 721    9.050  18.0    72.0   yes    male       yes
# 722    3.850  11.0    60.5   yes  female        no
# 723    9.825  15.0    64.9    no  female        no
# 724    7.100  10.0    67.7    no    male        no
#
# [725 rows x 6 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      LungCap   Age  Height Smoke  Gender Caesarean
# 0      6.475   6.0    62.1    no    male        no
# 1     10.125  18.0    74.7   yes  female        no
# 2      9.550  16.0    69.7    no  female       yes
# 3     11.125  14.0    71.0    no    male        no
# 4      4.800   5.0    56.9    no    male        no
# ..       ...   ...     ...   ...     ...       ...
# 720    5.725   9.0    56.0    no  female        no
# 721    9.050  18.0    72.0   yes    male       yes
# 722    3.850  11.0    60.5   yes  female        no
# 723    9.825  15.0    64.9    no  female        no
# 724    7.100  10.0    67.7    no    male        no
#
# [725 rows x 6 columns]>

# %%
data['Gender'].value_counts()
# Out:
# male      366
# female    357
# Name: Gender, dtype: int64

# %%
data['Gender'].value_counts(normalize=True)
# Out:
# male      0.506224
# female    0.493776
# Name: Gender, dtype: float64

# %% [markdown]
# Univariate Analysis

# %%
fig,axes=plt.subplots(1,3,figsize=(15,5))
data['Gender'].value_counts().plot.pie(explode = [0,0], autopct = '%1.0f%%', ax=axes[0], shadow = True)
data['Smoke'].value_counts().plot.pie(explode =[0.2,0], autopct = '%1.0f%%', ax=axes[1], shadow = True)
data['Caesarean'].value_counts().plot.pie(explode = [0.1,0],autopct ='%1.0f%%' ,ax=axes[2], shadow = True)
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(16,10))
sns.countplot('Caesarean', data=data, ax=axes[0,0])
sns.countplot('Smoke', data=data, ax=axes[0,1])
sns.countplot('Gender', data=data, ax=axes[0,2])
sns.distplot(data['Height'], ax=axes[1,0])
sns.distplot(data['LungCap'], kde=False, ax=axes [1,1])
sns.distplot(data['Age'], kde=True, ax=axes [1,2])
plt.show()

# %%
data=np.random.randn(10000)
x=np.sort(data)
y=1.*np.arange(len(data))/len(data)-1
#plot CDF
plt.plot(x,y)
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
data1 = pd.read_csv(r"/Users/udays/Downloads/LungCap.csv")
df = pd.DataFrame(data)

# %%
fig=plt.figure(figsize=(15,6))
sns.countplot(data=data1, x='Gender',hue='Age', palette='Accent') 
plt.title("GENDER VS AGE") 
plt.show()

# %%
fig=plt.figure(figsize=(15,6))
sns.countplot(data=data1, x='LungCap',hue='Gender', palette='Accent') 
plt.title("LungCap VS Gender") 
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(15,6))
sns.boxplot(y= 'Age', data=data1, x='Caesarean', ax=axes[0])
axes[0].set_title('CAESAREAN VS AGE',color='darkblue')
sns.boxplot(y='LungCap',data=data1,x='Gender',ax=axes[1])
axes[1].set_title('GENDER VS LUNG CAPACITY', color='indigo')
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(15,6))
sns.violinplot(y= 'LungCap', data=data1, x='Smoke', ax=axes[0])
axes[0].set_title('Smoke vs LungCap',color='darkblue')
sns.violinplot(y='Height',data=data1,x='Smoke',ax=axes[1])
axes[1].set_title('height vs Smoke', color='indigo')
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(15,6))
sns.boxplot(y= 'Age', data=data1, x='Smoke', ax=axes[0])
axes[0].set_title('Smoke vs Age',color='darkblue')
sns.violinplot(y='Height',data=data1,x='Gender',ax=axes[1])
axes[1].set_title('Gender vs height', color='indigo')
plt.show()

# %%
sns.swarmplot(x='Caesarean',y='LungCap',data=data1)
plt.suptitle("Lung Cap vs Caesarean")
plt.show()

# %%
sns.jointplot(x='Age',y='Height',data=data1, kind='reg')
plt.suptitle("Age vs Height")
plt.show()

# %%
sns.jointplot(x='LungCap',y='Age',data=data1, kind='reg')
plt.suptitle("LungCap vs Age")
plt.show()

# %%
sns.jointplot(x='LungCap',y='Height',data=data1, kind='reg')
plt.suptitle("LungCap vs Height")
plt.show()

# %%
fig=plt.figure(figsize=(8,6))
sns.countplot(x='Gender', data=data1, hue='Smoke') 
plt.title('Gender vs Smoke') 
plt.show()

# %%
fig=plt.figure(figsize=(8,6))
sns.countplot(x='Smoke',data=data1, hue='Age') 
plt.title('Smoke vs Age') 
plt.show()

# %%
fig=plt.figure(figsize=(10,6))
ct=pd.crosstab(index=data1['Gender'], columns=data1['Caesarean'])
plt.bar(ct.index,ct['yes'],label='Born by Caesarean')
plt.bar(ct.index,ct['no'],bottom=ct['yes'],label='Not Born by Caesarean')
plt.xlabel('Gender')
plt.title('GENDER VS CAESAREAN', color='purple')
plt.legend()
plt.show()
