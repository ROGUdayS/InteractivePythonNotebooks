# %%
# numpy         Numerical Calculations
# pandas        Data Exploration, cleaning, etc.
# matplotlib    Data Visualization
# seaborn       Advanced Data Visualization
# scipy         Scientific Calculations
# statistics    Statistical Functions
# sklearn       Machine Learning Algorithms
# tensorflow    Deep Learning Framework
# pytorch       Deep Learning Framework
# keras         Integrated with tensorflow
# cv2           Computer Vision , dealing with images colors and videos
# nltk          Natural Langauge Processing toolkit
# textblob      NLP

# %%
import numpy as np

# %%
# Arrays

# %%
arr1=np.array(5)

# %%
arr1
# Out:
# array(5)

# %%
arr2=np.array([2,5,4,7,3,6,9])

# %%
arr2
# Out:
# array([2, 5, 4, 7, 3, 6, 9])

# %%
arr3=np.array([[3,4,5],[2,5,7]])

# %%
arr3
# Out:
# array([[3, 4, 5],
#        [2, 5, 7]])

# %%
arr4=np.array([[[2,3,4,5],[4,5,6,7]],[[1,2,3,4],[4,5,6,8]]])

# %%
arr4
# Out:
# array([[[2, 3, 4, 5],
#         [4, 5, 6, 7]],
#
#        [[1, 2, 3, 4],
#         [4, 5, 6, 8]]])

# %%
# Attributes of numpy array
# -size   : total number of elements in the array
# -shape  : total number of elements in each axis of the array
# -ndim   : number of dimensions/axes on the array
# -dtype  : data type of the elements of the array

# %%
arr1
# Out:
# array(5)

# %%
arr1.size
# Out:
# 1

# %%
arr1.shape
# Out:
# ()

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr1.ndim
# Out:
# 0

# %%
arr2
# Out:
# array([2, 5, 4, 7, 3, 6, 9])

# %%
arr2.size
# Out:
# 7

# %%
arr2.shape
# Out:
# (7,)

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
arr2.ndim
# Out:
# 1

# %%
arr3
# Out:
# array([[3, 4, 5],
#        [2, 5, 7]])

# %%
arr3.size
# Out:
# 6

# %%
arr3.shape
# Out:
# (2, 3)

# %%
arr3.dtype
# Out:
# dtype('int64')

# %%
arr3.ndim
# Out:
# 2

# %%
arr4
# Out:
# array([[[2, 3, 4, 5],
#         [4, 5, 6, 7]],
#
#        [[1, 2, 3, 4],
#         [4, 5, 6, 8]]])

# %%
arr4.size
# Out:
# 16

# %%
arr4.shape
# Out:
# (2, 2, 4)

# %%
arr4.dtype
# Out:
# dtype('int64')

# %%
arr4.ndim
# Out:
# 3

# %%
# int         :     int8, int16, int32, int64, uint8, uint16, uint32, etc.
# float       :     float16,float32, etc.
# str         :     object
# int8        :  -2^(n-1) to (2^(n-1))-1 : -2^7 to (2^7)-1 : -128 to 127
# uint8       :   0 to (2^n)-1 : 0 to (2^8)-1: 0 to 255
# int16       : -2^15 to (2^15)-1 : -32768 to 32767
# uint16      :   0 to (2^16)-1: 0 to 65535

# %%
arr5=np.array([[[2,3,4],[4,5,6]],[[1,2,3],[4,5,6]],[[2,4,5],[4,5,6]]])

# %%
arr5.shape
# Out:
# (3, 2, 3)

# %%
arr3
# Out:
# array([[3, 4, 5],
#        [2, 5, 7]])

# %%
arr3.shape
# Out:
# (2, 3)

# %%
arr3=arr3.reshape(3,2)
arr3
# Out:
# array([[3, 4],
#        [5, 2],
#        [5, 7]])

# %%
arr3.reshape(6,1)

# %%
arr3.reshape(1,6)

# %%
arr3.reshape(6)

# %%
arr3.reshape(1,1,6)

# %%
arr3.reshape(1,6,1)

# %%
arr3.reshape(6,1,1)

# %%
arr3.reshape(1,2,3)

# %%
arr3.reshape(1,3,2)

# %%
arr3.reshape(2,1,3)

# %%
arr3.reshape(2,3,1)

# %%
arr3.reshape(3,1,2)

# %%
arr3.reshape(3,2,1)

# %%
arr3.reshape(3,1,2,1)
# Out:
# array([[[[3],
#          [4]]],
#
#
#        [[[5],
#          [2]]],
#
#
#        [[[5],
#          [7]]]])

# %%
arr4
# Out:
# array([[[2, 3, 4, 5],
#         [4, 5, 6, 7]],
#
#        [[1, 2, 3, 4],
#         [4, 5, 6, 8]]])

# %%
# how many different shapes can be found when reshaped in 1D and 2D

# %%
arr4.reshape(16)
# Out:
# array([2, 3, 4, 5, 4, 5, 6, 7, 1, 2, 3, 4, 4, 5, 6, 8])

# %%
arr4.reshape(16,1)
# Out:
# array([[2],
#        [3],
#        [4],
#        [5],
#        [4],
#        [5],
#        [6],
#        [7],
#        [1],
#        [2],
#        [3],
#        [4],
#        [4],
#        [5],
#        [6],
#        [8]])

# %%
arr4.reshape(1,16)
# Out:
# array([[2, 3, 4, 5, 4, 5, 6, 7, 1, 2, 3, 4, 4, 5, 6, 8]])

# %%
arr4.reshape(2,8)
# Out:
# array([[2, 3, 4, 5, 4, 5, 6, 7],
#        [1, 2, 3, 4, 4, 5, 6, 8]])

# %%
arr4.reshape(8,2)
# Out:
# array([[2, 3],
#        [4, 5],
#        [4, 5],
#        [6, 7],
#        [1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 8]])

# %%
arr4.reshape(4,4)
# Out:
# array([[2, 3, 4, 5],
#        [4, 5, 6, 7],
#        [1, 2, 3, 4],
#        [4, 5, 6, 8]])

# %%
# Random module in numpy

# %%
np.random.randint(100)
# Out:
# 93

# %%
np.random.randint(0,100,10)
# Out:
# array([41, 61, 10, 65,  9, 59, 18,  5, 82, 46])

# %%
otp=np.random.randint(0,10,6)
print(otp)
# Out:
# [9 3 4 2 6 5]

# %%
np.random.seed(13)
otp=np.random.randint(0,10,6)
print(otp)
# Out:
# [2 0 0 6 2 4]

# %%
np.random.seed(4)
a1=np.random.randint(0,10,10)
a1
# Out:
# array([7, 5, 1, 8, 7, 8, 2, 9, 7, 7])

# %%
np.unique(a1)
# Out:
# array([1, 2, 5, 7, 8, 9])

# %%
np.unique(a1,return_counts=True)
# Out:
# (array([1, 2, 5, 7, 8, 9]), array([1, 1, 1, 4, 2, 1]))

# %%
np.sum(a1)
# Out:
# 61

# %%
np.product(a1)
# Out:
# 13829760

# %%
np.mean(a1)
# Out:
# 6.1

# %%
np.size(a1)
# Out:
# 10

# %%
np.median(a1)
# Out:
# 7.0

# %%
np.std(a1)
# Out:
# 2.507987240796891

# %%
np.var(a1)
# Out:
# 6.290000000000001

# %%
np.min(a1)
# Out:
# 1

# %%
np.max(a1)
# Out:
# 9

# %%
np.argmin(a1)
# Out:
# 2

# %%
np.argmax(a1)
# Out:
# 7

# %%
a1
# Out:
# array([7, 5, 1, 8, 7, 8, 2, 9, 7, 7])

# %%
np.random.seed(3)
a2=np.random.randint(0,20,8)
a2
# Out:
# array([10,  3,  8,  0, 19, 10, 11,  9])

# %%
a2.reshape(4,2)
# Out:
# array([[10,  3],
#        [ 8,  0],
#        [19, 10],
#        [11,  9]])

# %%
np.random.seed(3)
a2=np.random.randint(0,20,(2,4))
a2
# Out:
# array([[10,  3,  8,  0],
#        [19, 10, 11,  9]])

# %%
for i in range(0,5,1):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
np.arange(0,5,1)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.arange(12,36,3)
# Out:
# array([12, 15, 18, 21, 24, 27, 30, 33])

# %%
np.arange(43,12,-7)
# Out:
# array([43, 36, 29, 22, 15])
