# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Series      1D
# DataFrames  2D
# Panels      3D
# 4D Panels   4D

# %%
a1=[2,4,6,8,10,12]

# %%
a1[-1]
# Out:
# 12

# %%
s1=pd.Series(a1)
s1
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5    12
# dtype: int64

# %%
s1[2]
# Out:
# 6

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
a2=(3,5,2,4,3)
s2=pd.Series(a2)
s2
# Out:
# 0    3
# 1    5
# 2    2
# 3    4
# 4    3
# dtype: int64

# %%
a3=np.array([3,4,5,6,7,8,9,2])
s3=pd.Series(a3)
s3
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# 6    9
# 7    2
# dtype: int64

# %%
a3=np.array([3,4,5,6,7,8,9,2])
s3=pd.Series(a3,index=['Alpha','Bravo','Charlie','Delta','Echo','Foxtrot','Golf','Hotel'])
s3
# Out:
# Alpha      3
# Bravo      4
# Charlie    5
# Delta      6
# Echo       7
# Foxtrot    8
# Golf       9
# Hotel      2
# dtype: int64

# %%
s3['Echo']
# Out:
# 7

# %%
a4={'a':5,'c':9,'f':8,'d':6,'g':9,'e':2,'j':6}
s4=pd.Series(a4)
s4
# Out:
# a    5
# c    9
# f    8
# d    6
# g    9
# e    2
# j    6
# dtype: int64

# %%
s4[0]
# Out:
# 5

# %%
s4['a']
# Out:
# 5

# %%
s4
# Out:
# a    5
# c    9
# f    8
# d    6
# g    9
# e    2
# j    6
# dtype: int64

# %%
s4.index
# Out:
# Index(['a', 'c', 'f', 'd', 'g', 'e', 'j'], dtype='object')

# %%
s4.values
# Out:
# array([5, 9, 8, 6, 9, 2, 6])

# %%
# DataFrames: combination of multiple Series

# %%
cars={'brand':['Volvo','BMW','Merc','Jaquar','Porsche'],'sales':[23,45,32,12,18],'rating':[6.5,7.6,6.2,7.7,9.3]}

# %%
cars
# Out:
# {'brand': ['Volvo', 'BMW', 'Merc', 'Jaquar', 'Porsche'],
#  'sales': [23, 45, 32, 12, 18],
#  'rating': [6.5, 7.6, 6.2, 7.7, 9.3]}

# %%
d1=pd.DataFrame(cars)
d1
# Out:
#      brand  sales  rating
# 0    Volvo     23     6.5
# 1      BMW     45     7.6
# 2     Merc     32     6.2
# 3   Jaquar     12     7.7
# 4  Porsche     18     9.3

# %%
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.ndim
# Out:
# 2

# %%
d1.shape
# Out:
# (5, 3)

# %%
d1.dtypes
# Out:
# brand      object
# sales       int64
# rating    float64
# dtype: object

# %%
# Task
# generate an array of 30 random numbers between 35 and 50 in the shape(5,6). use seed as 12. name the array as b1.
# create a list of 6 subject names. Name the list as subjects.
# create a list of 5 student names. Name the list as students.

# %%
np.random.seed(12)
b1=np.random.randint(35,50,(5,6))
subjects=['Math','Computers','Sports','Chemistry','Botany','Zoology']
students=['Jacob','George','Mark','Luke','Kevin']
b1
# Out:
# array([[46, 46, 41, 48, 36, 37],
#        [38, 38, 47, 35, 41, 36],
#        [39, 40, 48, 44, 37, 46],
#        [41, 45, 35, 40, 43, 47],
#        [48, 37, 44, 38, 49, 39]])

# %%
marks=pd.DataFrame(b1,index=students,columns=subjects)
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology
# Jacob     46         46      41         48      36       37
# George    38         38      47         35      41       36
# Mark      39         40      48         44      37       46
# Luke      41         45      35         40      43       47
# Kevin     48         37      44         38      49       39

# %%
marks['Math']
# Out:
# Jacob     46
# George    38
# Mark      39
# Luke      41
# Kevin     48
# Name: Math, dtype: int64

# %%
marks['Sports']
# Out:
# Jacob     41
# George    47
# Mark      48
# Luke      35
# Kevin     44
# Name: Sports, dtype: int64

# %%
marks.index
# Out:
# Index(['Jacob', 'George', 'Mark', 'Luke', 'Kevin'], dtype='object')

# %%
marks.values
# Out:
# array([[46, 46, 41, 48, 36, 37],
#        [38, 38, 47, 35, 41, 36],
#        [39, 40, 48, 44, 37, 46],
#        [41, 45, 35, 40, 43, 47],
#        [48, 37, 44, 38, 49, 39]])

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology
# Jacob     46         46      41         48      36       37
# George    38         38      47         35      41       36
# Mark      39         40      48         44      37       46
# Luke      41         45      35         40      43       47
# Kevin     48         37      44         38      49       39

# %%
marks.describe()
# Out:
#             Math  Computers     Sports  Chemistry     Botany    Zoology
# count   5.000000   5.000000   5.000000    5.00000   5.000000   5.000000
# mean   42.400000  41.200000  43.000000   41.00000  41.200000  41.000000
# std     4.393177   4.086563   5.244044    5.09902   5.215362   5.147815
# min    38.000000  37.000000  35.000000   35.00000  36.000000  36.000000
# 25%    39.000000  38.000000  41.000000   38.00000  37.000000  37.000000
# 50%    41.000000  40.000000  44.000000   40.00000  41.000000  39.000000
# 75%    46.000000  45.000000  47.000000   44.00000  43.000000  46.000000
# max    48.000000  46.000000  48.000000   48.00000  49.000000  47.000000

# %%
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Jacob to Kevin
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Math       5 non-null      int64
#  1   Computers  5 non-null      int64
#  2   Sports     5 non-null      int64
#  3   Chemistry  5 non-null      int64
#  4   Botany     5 non-null      int64
#  5   Zoology    5 non-null      int64
# dtypes: int64(6)
# memory usage: 452.0+ bytes

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology
# Jacob     46         46      41         48      36       37
# George    38         38      47         35      41       36
# Mark      39         40      48         44      37       46
# Luke      41         45      35         40      43       47
# Kevin     48         37      44         38      49       39

# %%
marks.sum()
# Out:
# Math         212
# Computers    206
# Sports       215
# Chemistry    205
# Botany       206
# Zoology      205
# dtype: int64

# %%
marks.sum(axis=0)
# Out:
# Math         212
# Computers    206
# Sports       215
# Chemistry    205
# Botany       206
# Zoology      205
# dtype: int64

# %%
marks.sum(axis=1)
# Out:
# Jacob     254
# George    235
# Mark      254
# Luke      251
# Kevin     255
# dtype: int64

# %%
marks['Total']=marks.sum(axis=1)

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology  Total
# Jacob     46         46      41         48      36       37    254
# George    38         38      47         35      41       36    235
# Mark      39         40      48         44      37       46    254
# Luke      41         45      35         40      43       47    251
# Kevin     48         37      44         38      49       39    255

# %%
marks['Total_marks']=marks['Math']+marks['Computers']+marks['Sports']+marks['Chemistry']+marks['Botany']+marks['Zoology']

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology  Total  \
# Jacob     46         46      41         48      36       37    254
# George    38         38      47         35      41       36    235
# Mark      39         40      48         44      37       46    254
# Luke      41         45      35         40      43       47    251
# Kevin     48         37      44         38      49       39    255
#
#         Total_marks
# Jacob           254
# George          235
# Mark            254
# Luke            251
# Kevin           255

# %%
marks['Percentage']=round((marks['Total']/300)*100,2)

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology  Total  \
# Jacob     46         46      41         48      36       37    254
# George    38         38      47         35      41       36    235
# Mark      39         40      48         44      37       46    254
# Luke      41         45      35         40      43       47    251
# Kevin     48         37      44         38      49       39    255
#
#         Total_marks  Percentage
# Jacob           254       84.67
# George          235       78.33
# Mark            254       84.67
# Luke            251       83.67
# Kevin           255       85.00

# %%
marks=marks.drop(columns=['Percentage'])

# %%
marks.drop(columns=['Total_marks'],inplace=True)

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology  Total
# Jacob     46         46      41         48      36       37    254
# George    38         38      47         35      41       36    235
# Mark      39         40      48         44      37       46    254
# Luke      41         45      35         40      43       47    251
# Kevin     48         37      44         38      49       39    255

# %%
marks.drop('Kevin')
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology  Total
# Jacob     46         46      41         48      36       37    254
# George    38         38      47         35      41       36    235
# Mark      39         40      48         44      37       46    254
# Luke      41         45      35         40      43       47    251

# %%
marks
# Out:
#         Math  Computers  Sports  Chemistry  Botany  Zoology  Total
# Jacob     46         46      41         48      36       37    254
# George    38         38      47         35      41       36    235
# Mark      39         40      48         44      37       46    254
# Luke      41         45      35         40      43       47    251
# Kevin     48         37      44         38      49       39    255

# %%
df=pd.read_csv("/content/drive/MyDrive/Adverk/Adverk AI 2023 06 batch/Datasets/CarPrice_Assignment.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# pd.DataFrame()    # to create df from dict or arrays
# pd.read_csv()
# pd.read_excel()
# pd.read_html()
# pd.read_json()
# pd.read_table()
# pd.read_sql()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.head(2)
# Out:
#    car_ID  symboling              CarName fueltype aspiration doornumber  \
# 0       1          3   alfa-romero giulia      gas        std        two
# 1       2          3  alfa-romero stelvio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
#
# [2 rows x 26 columns]

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
df.tail(3)
# Out:
#      car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 202     203         -1  volvo 244dl      gas        std       four   sedan
# 203     204         -1    volvo 246   diesel      turbo       four   sedan
# 204     205         -1  volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 202        rwd          front      109.1  ...         173        mpfi
# 203        rwd          front      109.1  ...         145         idi
# 204        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
# ...

# %%
df[2:10]
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#      carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 2  hatchback        rwd          front       94.5  ...         152
# 3      sedan        fwd          front       99.8  ...         109
# ...

# %%
df[13:18]
# Out:
#     car_ID  symboling CarName fueltype aspiration doornumber carbody  \
# 13      14          0  bmw x3      gas        std       four   sedan
# 14      15          1  bmw z4      gas        std       four   sedan
# 15      16          0  bmw x4      gas        std       four   sedan
# 16      17          0  bmw x5      gas        std        two   sedan
# 17      18          0  bmw x3      gas        std       four   sedan
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 13        rwd          front      101.2  ...         164        mpfi
# 14        rwd          front      103.5  ...         164        mpfi
# 15        rwd          front      103.5  ...         209        mpfi
# 16        rwd          front      103.5  ...         209        mpfi
# 17        rwd          front      110.0  ...         209        mpfi
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.sample()
# Out:
#     car_ID  symboling    CarName fueltype aspiration doornumber    carbody  \
# 59      60          1  mazda 626      gas        std        two  hatchback
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 59        fwd          front       98.8  ...         122        2bbl
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 59       3.39    3.39              8.6         84     4800      26
#
#     highwaympg   price
# 59          32  8845.0
#
# [1 rows x 26 columns]

# %%
df.sample(4,random_state=12)
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 32       33          1      honda civic      gas        std        two
# 6         7          1       audi 100ls      gas        std       four
# 135     136          2       saab 99gle      gas        std       four
# 124     125          3  plymouth duster      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 32   hatchback        fwd          front       93.7  ...          79
# 6        sedan        fwd          front      105.8  ...         136
# 135      sedan        fwd          front       99.1  ...         121
# 124  hatchback        rwd          front       95.9  ...         156
#
#      fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 32         1bbl       2.91    3.07             10.1         60     5500
# 6          mpfi       3.19    3.40              8.5        110     5500
# ...

# %%
df['CarName']
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
df[['CarName','car_ID']]
# Out:
#                       CarName  car_ID
# 0          alfa-romero giulia       1
# 1         alfa-romero stelvio       2
# 2    alfa-romero Quadrifoglio       3
# 3                 audi 100 ls       4
# 4                  audi 100ls       5
# ..                        ...     ...
# 200           volvo 145e (sw)     201
# 201               volvo 144ea     202
# 202               volvo 244dl     203
# 203                 volvo 246     204
# 204               volvo 264gl     205
#
# [205 rows x 2 columns]

# %%
df.iloc[5:12,1:5]
# Out:
#     symboling              CarName fueltype aspiration
# 5           2             audi fox      gas        std
# 6           1           audi 100ls      gas        std
# 7           1            audi 5000      gas        std
# 8           1            audi 4000      gas      turbo
# 9           0  audi 5000s (diesel)      gas      turbo
# 10          2             bmw 320i      gas        std
# 11          0             bmw 320i      gas        std

# %%
df.iloc[195:200,7:13]
# Out:
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight
# 195        rwd          front      104.3      188.8      67.2       57.5
# 196        rwd          front      104.3      188.8      67.2       56.2
# 197        rwd          front      104.3      188.8      67.2       57.5
# 198        rwd          front      104.3      188.8      67.2       56.2
# 199        rwd          front      104.3      188.8      67.2       57.5

# %%
df.iloc[0:205,0:26]
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.iloc[:,:]
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.iloc[:,3:7]
# Out:
#     fueltype aspiration doornumber      carbody
# 0        gas        std        two  convertible
# 1        gas        std        two  convertible
# 2        gas        std        two    hatchback
# 3        gas        std       four        sedan
# 4        gas        std       four        sedan
# ..       ...        ...        ...          ...
# 200      gas        std       four        sedan
# 201      gas      turbo       four        sedan
# 202      gas        std       four        sedan
# 203   diesel      turbo       four        sedan
# 204      gas      turbo       four        sedan
#
# [205 rows x 4 columns]

# %%
df.iloc[195:200,7:13]
# Out:
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight
# 195        rwd          front      104.3      188.8      67.2       57.5
# 196        rwd          front      104.3      188.8      67.2       56.2
# 197        rwd          front      104.3      188.8      67.2       57.5
# 198        rwd          front      104.3      188.8      67.2       56.2
# 199        rwd          front      104.3      188.8      67.2       57.5

# %%
df.iloc[[3,7,10,12,5],[3,9,15,6]]
# Out:
#    fueltype  wheelbase cylindernumber carbody
# 3       gas       99.8           four   sedan
# 7       gas      105.8           five   wagon
# 10      gas      101.2           four   sedan
# 12      gas      101.2            six   sedan
# 5       gas       99.8           five   sedan

# %%
df.loc[[3,7,10,12,5],['fueltype','wheelbase','cylindernumber','carbody']]
# Out:
#    fueltype  wheelbase cylindernumber carbody
# 3       gas       99.8           four   sedan
# 7       gas      105.8           five   wagon
# 10      gas      101.2           four   sedan
# 12      gas      101.2            six   sedan
# 5       gas       99.8           five   sedan
