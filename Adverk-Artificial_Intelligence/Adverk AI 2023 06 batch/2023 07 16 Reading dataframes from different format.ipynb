# %%
import pandas as pd

# %%
pd.read_csv("/content/drive/MyDrive/Adverk/Adverk AI 2023 06 batch/Datasets/Cars.csv",sep=";")
# Out:
#                            Car   MPG  Cylinders Displacement Horsepower  \
# 0    Chevrolet Chevelle Malibu  18,0          8        307,0      130,0
# 1            Buick Skylark 320  15,0          8        350,0      165,0
# 2           Plymouth Satellite  18,0          8        318,0      150,0
# 3                AMC Rebel SST  16,0          8        304,0      150,0
# 4                  Ford Torino  17,0          8        302,0      140,0
# ..                         ...   ...        ...          ...        ...
# 401            Ford Mustang GL  27,0          4        140,0      86,00
# 402          Volkswagen Pickup  44,0          4        97,00      52,00
# 403              Dodge Rampage  32,0          4        135,0      84,00
# 404                Ford Ranger  28,0          4        120,0      79,00
# 405                 Chevy S-10  31,0          4        119,0      82,00
#
#      Weight Acceleration  Model  Origin
# 0      3504         12,0     70      US
# ...

# %%
pd.read_table("/content/drive/MyDrive/Adverk/Adverk AI 2023 06 batch/Datasets/Cars.csv")
# Out:
#     Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0    Chevrolet Chevelle Malibu;18,0;8;307,0;130,0;3...
# 1    Buick Skylark 320;15,0;8;350,0;165,0;3693;11,5...
# 2    Plymouth Satellite;18,0;8;318,0;150,0;3436;11,...
# 3     AMC Rebel SST;16,0;8;304,0;150,0;3433;12,0;70;US
# 4       Ford Torino;17,0;8;302,0;140,0;3449;10,5;70;US
# ..                                                 ...
# 401  Ford Mustang GL;27,0;4;140,0;86,00;2790;15,6;8...
# 402  Volkswagen Pickup;44,0;4;97,00;52,00;2130;24,6...
# 403   Dodge Rampage;32,0;4;135,0;84,00;2295;11,6;82;US
# 404     Ford Ranger;28,0;4;120,0;79,00;2625;18,6;82;US
# 405      Chevy S-10;31,0;4;119,0;82,00;2720;19,4;82;US
#
# [406 rows x 1 columns]

# %%
pd.read_table("/content/drive/MyDrive/Adverk/Adverk AI 2023 06 batch/Datasets/spam.tsv")
# Out:
#      label                                            message  length  punct
# 0      ham  Go until jurong point, crazy.. Available only ...     111      9
# 1      ham                      Ok lar... Joking wif u oni...      29      6
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3      ham  U dun say so early hor... U c already then say...      49      6
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61      2
# ...    ...                                                ...     ...    ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1
#
# [5572 rows x 4 columns]

# %%
pd.read_csv("/content/drive/MyDrive/Adverk/Adverk AI 2023 06 batch/Datasets/spam.tsv",sep="\t")
# Out:
#      label                                            message  length  punct
# 0      ham  Go until jurong point, crazy.. Available only ...     111      9
# 1      ham                      Ok lar... Joking wif u oni...      29      6
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3      ham  U dun say so early hor... U c already then say...      49      6
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61      2
# ...    ...                                                ...     ...    ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1
#
# [5572 rows x 4 columns]

# %%
df=pd.read_csv("/content/drive/MyDrive/Adverk/Adverk AI 2023 06 batch/Datasets/IRIS Test data.txt",
            sep=";",header=None)

# %%
df=df.rename(columns={0:"C1",1:"C2",2:"C3",3:"C4",4:"C5",5:"C6",6:"C7",7:"C8",8:"Species"})

# %%
df
# Out:
#      C1    C2   C3    C4   C5    C6   C7    C8     Species
# 0   5.5  0.33  4.2  0.91  1.4  0.06  0.2  0.04      setosa
# 1   4.9  0.16  3.1  0.45  1.5  0.08  0.2  0.04      setosa
# 2   5.0  0.19  3.2  0.50  1.2  0.03  0.2  0.04      setosa
# 3   5.5  0.33  3.5  0.62  1.3  0.05  0.2  0.04      setosa
# 4   4.9  0.16  3.6  0.66  1.4  0.06  0.1  0.01      setosa
# 5   4.4  0.02  3.0  0.41  1.3  0.05  0.2  0.04      setosa
# 6   5.1  0.22  3.4  0.58  1.5  0.08  0.2  0.04      setosa
# 7   5.0  0.19  3.5  0.62  1.3  0.05  0.3  0.08      setosa
# 8   4.5  0.05  2.3  0.12  1.3  0.05  0.3  0.08      setosa
# 9   4.4  0.02  3.2  0.50  1.3  0.05  0.2  0.04      setosa
# 10  5.0  0.19  3.5  0.62  1.6  0.10  0.6  0.20      setosa
# 11  5.1  0.22  3.8  0.75  1.9  0.15  0.4  0.12      setosa
# 12  4.8  0.13  3.0  0.41  1.4  0.06  0.3  0.08      setosa
# 13  5.1  0.22  3.8  0.75  1.6  0.10  0.2  0.04      setosa
# 14  4.6  0.08  3.2  0.50  1.4  0.06  0.2  0.04      setosa
# ...
